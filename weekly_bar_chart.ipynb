# %%
# importing altair and pandas for use in visualizations.
import altair as alt
import pandas as pd

# loading the crime csv from the zip file and displaying it's head
# this fails if the macosx folder remains in the zip
crime = pd.read_csv("crime.csv.zip", encoding="ISO-8859-1", compression='zip')
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# 0      Sunday    13    Part One   LINCOLN ST  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST  42.275365 -71.090361
#
#                       Location
# 0  (42.35779134, -71.13937053)
# 1  (42.30682138, -71.06030035)
# 2  (42.34658879, -71.07242943)
# 3  (42.33418175, -71.07866441)
# 4  (42.27536542, -71.09036101)

# %%
# adding a daily crime count column to the dataframe using .groupby and .transform

crime["day_count"] = crime.groupby("DAY_OF_WEEK")["DAY_OF_WEEK"].transform("size")
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# 0      Sunday    13    Part One   LINCOLN ST  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST  42.275365 -71.090361
#
#                       Location  day_count
# 0  (42.35779134, -71.13937053)      40313
# 1  (42.30682138, -71.06030035)      46383
# 2  (42.34658879, -71.07242943)      45679
# 3  (42.33418175, -71.07866441)      45679
# 4  (42.27536542, -71.09036101)      45679

# %%
# adding a per offense code/weekday total to the dataframe
crime["crime_weekday_total"] = crime.groupby(["DAY_OF_WEEK", "OFFENSE_CODE_GROUP"])["OFFENSE_CODE_GROUP"].transform("size")
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# 0      Sunday    13    Part One   LINCOLN ST  42.357791 -71.139371
# 1     Tuesday     0    Part Two     HECLA ST  42.306821 -71.060300
# 2      Monday    19  Part Three  CAZENOVE ST  42.346589 -71.072429
# 3      Monday    21  Part Three   NEWCOMB ST  42.334182 -71.078664
# 4      Monday    21  Part Three     DELHI ST  42.275365 -71.090361
#
#                       Location  day_count  crime_weekday_total
# 0  (42.35779134, -71.13937053)      40313                 3080
# 1  (42.30682138, -71.06030035)      46383                 2071
# 2  (42.34658879, -71.07242943)      45679                 1701
# 3  (42.33418175, -71.07866441)      45679                 1539
# 4  (42.27536542, -71.09036101)      45679                 1539

# %%
# sorting values and dropping colums with less than 300 offenses(eg. aircraft or homicide)
crime = crime.sort_values("crime_weekday_total", ascending=False)
crime = crime.drop(crime[crime["crime_weekday_total"] < 300].index)
crime.head()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 34813       I182033514          3831  Motor Vehicle Accident Response
# 174738      I162098218          3802  Motor Vehicle Accident Response
# 191607      I162080164          3803  Motor Vehicle Accident Response
# 145666      I172022891          3803  Motor Vehicle Accident Response
# 205646      I162064985          3831  Motor Vehicle Accident Response
#
#                           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 34813   M/V - LEAVING SCENE - PROPERTY DAMAGE       B3            470
# 174738        M/V ACCIDENT - PROPERTY  DAMAGE      C11            345
# 191607         M/V ACCIDENT - PERSONAL INJURY       B2
# 145666         M/V ACCIDENT - PERSONAL INJURY       C6
# 205646  M/V - LEAVING SCENE - PROPERTY DAMAGE      E13            579
#
#        SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 34813       NaN  2018-05-04 06:05:00  2018      5      Friday     6
# 174738      NaN  2016-12-02 09:22:00  2016     12      Friday     9
# 191607      NaN  2016-09-30 17:39:00  2016      9      Friday    17
# 145666      NaN  2017-03-24 05:45:00  2017      3      Friday     5
# 205646      NaN  2016-08-12 17:20:00  2016      8      Friday    17
#
#           UCR_PART             STREET        Lat       Long  \
# 34813   Part Three          ITASCA ST  42.275609 -71.100318
# 174738  Part Three         ARCADIA ST  42.301402 -71.063058
# 191607  Part Three  MASSACHUSETTS AVE        NaN        NaN
# 145666  Part Three                NaN        NaN        NaN
# 205646  Part Three          CENTRE ST  42.322770 -71.104455
#
#                            Location  day_count  crime_weekday_total
# 34813   (42.27560924, -71.10031808)      48495                 5852
# 174738  (42.30140245, -71.06305829)      48495                 5852
# 191607     (0.00000000, 0.00000000)      48495                 5852
# 145666     (0.00000000, 0.00000000)      48495                 5852
# 205646  (42.32277007, -71.10445458)      48495                 5852

# %%
# dropping duplicate weekday totals to collate only the unique values for representation
daily_totals = crime.drop_duplicates("crime_weekday_total")
daily_totals
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# 34813       I182033514          3831   Motor Vehicle Accident Response
# 183598      I162088675          3803   Motor Vehicle Accident Response
# 269734      I152103802          3820   Motor Vehicle Accident Response
# 283035      I152089019          3801   Motor Vehicle Accident Response
# 305123      I152064957          3802   Motor Vehicle Accident Response
# ...                ...           ...                               ...
# 289411      I152082116          3304  Assembly or Gathering Violations
# 47886       I182019645          1503                Firearm Violations
# 245956      I162021734          3111                 License Violation
# 263429      I162002851          1106                  Confidence Games
# 309223      I152060432          1501                Firearm Violations
#
#                                   OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 34813           M/V - LEAVING SCENE - PROPERTY DAMAGE       B3            470
# 183598                 M/V ACCIDENT - PERSONAL INJURY      C11            365
# 269734     M/V ACCIDENT INVOLVING PEDESTRIAN - INJURY       E5            733
# 283035                           M/V ACCIDENT - OTHER       B2            587
# 305123                M/V ACCIDENT - PROPERTY  DAMAGE      C11            348
# ...                                               ...      ...            ...
# 289411                    NOISY PARTY/RADIO-NO ARREST       B2            586
# 47886     WEAPON - OTHER - CARRYING / POSSESSING, ETC       B3            442
# 245956                      LICENSE PREMISE VIOLATION       C6            222
# 263429                FRAUD - CREDIT CARD / ATM FRAUD       C6            200
# 309223  WEAPON - FIREARM - CARRYING / POSSESSING, ETC       B2            319
#
#        SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 34813       NaN  2018-05-04 06:05:00  2018      5      Friday     6
# 183598      NaN  2016-10-29 21:10:00  2016     10    Saturday    21
# 269734      NaN  2015-12-16 17:09:00  2015     12   Wednesday    17
# 283035      NaN  2015-10-27 08:01:00  2015     10     Tuesday     8
# 305123      NaN  2015-08-06 12:21:00  2015      8    Thursday    12
# ...         ...                  ...   ...    ...         ...   ...
# 289411      NaN  2015-10-03 00:52:00  2015     10    Saturday     0
# 47886       NaN  2018-03-15 19:07:00  2018      3    Thursday    19
# 245956      NaN  2016-03-20 15:44:00  2016      3      Sunday    15
# 263429      NaN  2015-12-06 00:00:00  2015     12      Sunday     0
# 309223      NaN  2015-07-22 00:36:00  2015      7   Wednesday     0
#
#           UCR_PART          STREET        Lat       Long  \
# 34813   Part Three       ITASCA ST  42.275609 -71.100318
# 183598  Part Three     LONSDALE ST  42.291115 -71.058436
# 269734  Part Three     LAGRANGE ST  42.287454 -71.165322
# 283035  Part Three      TREMONT ST  42.332590 -71.100314
# 305123  Part Three  DORCHESTER AVE  42.304704 -71.059083
# ...            ...             ...        ...        ...
# 289411  Part Three     CHEROKEE ST  42.330477 -71.100727
# 47886     Part Two     WESTCOTT ST  42.293218 -71.078865
# 245956  Part Three     E SECOND ST  42.337307 -71.036470
# 263429    Part Two      W BROADWAY  42.342342 -71.056333
# 309223    Part Two       SEAVER ST  42.307160 -71.088236
#
#                            Location  day_count  crime_weekday_total
# 34813   (42.27560924, -71.10031808)      48495                 5852
# 183598  (42.29111533, -71.05843629)      44818                 5490
# 269734  (42.28745399, -71.16532231)      46729                 5251
# 283035  (42.33258958, -71.10031377)      46383                 5210
# 305123  (42.30470399, -71.05908258)      46656                 5187
# ...                             ...        ...                  ...
# 289411  (42.33047722, -71.10072736)      44818                  322
# 47886   (42.29321805, -71.07886455)      46656                  316
# 245956  (42.33730678, -71.03646955)      40313                  307
# 263429  (42.34234193, -71.05633276)      40313                  306
# 309223  (42.30715951, -71.08823566)      46729                  303
#
# [183 rows x 19 columns]

# %%
# adding a selection for offense type
selection = alt.selection_single(fields=["OFFENSE_CODE_GROUP"], bind="legend")

# disabling max row restriction to allow full dataset use
alt.data_transformers.disable_max_rows()

# constructing the chart - encoding the day of week on the x and daily total count on the y, with color being affected by offense code group & selection
# tooltip allows for exact crime numbers to be displayed
bar = alt.Chart(daily_totals).mark_bar().encode(x= "DAY_OF_WEEK", y= "crime_weekday_total", color=alt.condition(selection, "OFFENSE_CODE_GROUP:N", alt.value('lightgrey')), tooltip=['DAY_OF_WEEK', 'day_count', "OFFENSE_CODE_GROUP", "crime_weekday_total"]).add_selection(selection).properties(title="Daily Crime Totals for Each Weekday")

bar
# Out:
# /var/folders/r2/mpnzh7jj4gddjwxfgyd9hn6r0000gn/T/ipykernel_79959/1819793635.py:2: AltairDeprecationWarning: Deprecated in `altair=5.0.0`. Use selection_point instead.
#   selection = alt.selection_single(fields=["OFFENSE_CODE_GROUP"], bind="legend")
# /var/folders/r2/mpnzh7jj4gddjwxfgyd9hn6r0000gn/T/ipykernel_79959/1819793635.py:9: AltairDeprecationWarning: Deprecated in `altair=5.0.0`. Use add_params instead.
#   bar = alt.Chart(daily_totals).mark_bar().encode(x= "DAY_OF_WEEK", y= "crime_weekday_total", color=alt.condition(selection, "OFFENSE_CODE_GROUP:N", alt.value('lightgrey')), tooltip=['DAY_OF_WEEK', 'day_count', "OFFENSE_CODE_GROUP", "crime_weekday_total"]).add_selection(selection).properties(title="Daily Crime Totals for Each Weekday")
# alt.Chart(...)

# %%
bar.save("weekly_bar_chart.html")
