# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

alt.data_transformers.enable('default', max_rows=None)

import zipfile

zip_path = 'crime.csv.zip'  # Replace with your actual ZIP file path

with zipfile.ZipFile(zip_path, 'r') as z:
    csv_filename = z.namelist()[0]
    
    with z.open(csv_filename) as f:
        df = pd.read_csv(f)
df
# Out:
# /var/folders/_q/ytw8y5ys0f12ftzj6nh3w9kh0000gn/T/ipykernel_26145/1238126157.py:16: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           I182080058          2403  Disorderly Conduct
# 1           I182080053          3201       Property Lost
# 2           I182080052          2647               Other
# 3           I182080051           413  Aggravated Assault
# 4           I182080050          3122            Aircraft
# ...                ...           ...                 ...
# 327815   I050310906-00          3125     Warrant Arrests
# 327816   I030217815-08           111            Homicide
# 327817   I030217815-08          3125     Warrant Arrests
# 327818   I010370257-00          3125     Warrant Arrests
# 327819       142052550          3125     Warrant Arrests
#
# ...

# %%
grouped = df.groupby(['YEAR', 'MONTH', 'OFFENSE_CODE_GROUP']).size().reset_index(name='COUNT')
grouped['DATE'] = pd.to_datetime(grouped[['YEAR', 'MONTH']].assign(DAY=1)).dt.strftime('%Y-%m')


grouped.to_csv('grouped_crime_data.csv', index=False)
